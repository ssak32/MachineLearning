# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
master_frame_venture = pd.read_csv("master_df_SectorAnalysis1.csv", encoding='ISO-8859-1')

# %%
master_frame_venture = master_frame_venture.loc[(master_frame_venture['raised_amount_usd'] >= 5000000) & (master_frame_venture['raised_amount_usd'] <= 15000000)]

# %%
master_frame_venture.sort_values('raised_amount_usd', axis=0, ascending=False)
# Out:
#                      category_list country_code   funded_at  \
# 4594                 biotechnology          USA  11-03-2014
# 37447           big data analytics          USA  08-01-2014
# 19537                    messaging          USA  01-10-2005
# 1851                 biotechnology          USA  21-07-2010
# 15281          hardware + software          USA  07-11-2006
# ...                            ...          ...         ...
# 10802  reviews and recommendations          USA  01-06-2007
# 31288                    analytics          USA  24-05-2011
# 10869                  photography          USA  20-08-2014
# 10871                  photography          USA  01-06-2015
# 0                           drones          USA  05-11-2012
#
#                                funding_round_permalink funding_round_type  \
# 4594   /funding-round/b358b34617228299790f2b3f3e343662            venture
# 37447  /funding-round/6bbf6cac4cf2565afa4cf8625dadb834            venture
# ...

# %%
#pd.pivot_table(master_frame_venture, index=['country_code', 'sector'], values=['raised_amount_usd'], aggfunc=np.sum)
master_frame_venture.groupby(['country_code', 'sector']).raised_amount_usd.agg(['count', 'sum'])
# Out:
#                                                       count           sum
# country_code sector
# GBR          Automotive & Sports                         16  1.670516e+08
#              Cleantech / Semiconductors                 130  1.163990e+09
#              Entertainment                               56  4.827847e+08
#              Health                                      24  2.145375e+08
#              Manufacturing                               42  3.619403e+08
#              News, Search and Messaging                  73  6.157462e+08
#              Others                                     147  1.283624e+09
#              Social, Finance, Analytics, Advertising    133  1.089404e+09
# IND          Automotive & Sports                         13  1.369000e+08
#              Cleantech / Semiconductors                  20  1.653800e+08
#              Entertainment                               33  2.808300e+08
# ...
