# %% [markdown]
# # Multiple Linear Regression

# %%
#Importing pandas library to read CSV data file
import pandas as pd

#Importing numpy to perfom math on arrays
import numpy as np

#Importing statsmodels.formula to fit the regression model
# import statsmodels.formula.api as sm
import statsmodels.regression.linear_model as sm

# %%
#Reading CSV data file in Python
dataset = pd.read_csv('Companies-spends-and-profits.csv')

# %%
dataset
# Out:
#          City         IT  Staff_Training  Advertising     Profit
# 0       Paris  165349.20       236897.80    472784.20  182262.83
# 1        Rome  262597.70       182377.59    443898.53  172792.06
# 2        Rome  153442.52       172245.55    407934.54  162050.39
# 3       Paris  244372.42       138672.85    383299.62  282902.99
# 4        Rome  132207.34        92392.77    366268.42  266287.94
# ..        ...        ...             ...          ...        ...
# 66     London   78389.47       153773.43    199737.19  121313.01
# 67  Frankfurt   73994.56       121781.75    303319.16  120351.15
# 68  Frankfurt   67531.53       105751.03    304768.73  108733.99
# 69     London   77044.01        99181.34    150574.81  108551.04
# 70  Frankfurt   64664.71       139553.16    137961.61  107404.34
#
# [71 rows x 5 columns]

# %%
#Dividing dataset into X and y
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 4].values

# %%
X
# Out:
# array([['Paris', 165349.2, 236897.8, 472784.2],
#        ['Rome', 262597.7, 182377.59, 443898.53],
#        ['Rome', 153442.52, 172245.55, 407934.54],
#        ['Paris', 244372.42, 138672.85, 383299.62],
#        ['Rome', 132207.34, 92392.77, 366268.42],
#        ['Paris', 232876.9, 99824.72, 362862.36],
#        ['Rome', 214625.46, 247298.87, 227726.82],
#        ['Paris', 220298.23, 155530.06, 323876.68],
#        ['Paris', 220542.52, 138728.95, 322623.29],
#        ['Rome', 113334.88, 148679.27, 304982.62],
#        ['Rome', 182923.08, 220594.22, 229260.95],
#        ['Rome', 200672.96, 92790.62, 249744.55],
#        ['Rome', 93863.75, 227320.38, 249839.44],
#        ['Rome', 92992.39, 235495.07, 252664.93],
#        ['Paris', 119943.24, 256547.42, 256522.92],
#        ['Paris', 164523.62, 222626.84, 262776.23],
#        ['Rome', 78023.22, 222597.55, 264346.06],
#        ['Paris', 94657.26, 245077.58, 282574.32],
#        ['Paris', 92749.26, 224275.79, 294929.57],
# ...

# %%
y
# Out:
# array([182262.83, 172792.06, 162050.39, 282902.99, 266287.94, 176992.22,
#        146222.52, 255752.6 , 153452.77, 249759.96, 246222.95, 244259.4 ,
#        242585.52, 234307.35, 232602.65, 139927.04, 166992.93, 225370.37,
#        224266.9 , 228474.03, 282323.02, 120352.25, 208733.99, 208552.04,
#        207404.34, 205733.54, 205008.32, 203282.38, 202004.64,  99937.59,
#         97483.56,  97427.84,  96778.92,  96722.8 ,  96479.52,  90708.29,
#         89949.24,  82229.06,  82005.76,  78239.92,  77798.83,  72498.49,
#         69758.98,  65200.33,  64926.08,  49490.75, 191261.83, 191791.06,
#        191050.39, 181901.99, 166187.94, 156991.12, 156121.51, 155751.6 ,
#        151212.77, 159759.96, 156121.95, 154159.4 , 151585.51, 134307.35,
#        131601.65, 129917.04, 126991.93, 125370.37, 125166.9 , 128474.03,
#        121313.01, 120351.15, 108733.99, 108551.04, 107404.34])

# %% [markdown]
# ## Encoding categorical data to create the Dummy Variables

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
X[:, 0] = labelencoder.fit_transform(X[:, 0])
onehotencoder = OneHotEncoder(categorical_features = [0])
X = onehotencoder.fit_transform(X).toarray()
# Out:
# d:\gitrepositories\machinelearning\ml_env\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# d:\gitrepositories\machinelearning\ml_env\lib\site-packages\sklearn\preprocessing\_encoders.py:451: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)

# %%
X
# Out:
# array([[0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 0.0000000e+00,
#         1.6534920e+05, 2.3689780e+05, 4.7278420e+05],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.6259770e+05, 1.8237759e+05, 4.4389853e+05],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.5344252e+05, 1.7224555e+05, 4.0793454e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 0.0000000e+00,
#         2.4437242e+05, 1.3867285e+05, 3.8329962e+05],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         1.3220734e+05, 9.2392770e+04, 3.6626842e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 0.0000000e+00,
#         2.3287690e+05, 9.9824720e+04, 3.6286236e+05],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         2.1462546e+05, 2.4729887e+05, 2.2772682e+05],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00, 0.0000000e+00,
# ...

# %% [markdown]
# ## Adding Intercept column to X

# %%
# Creating a new array of given shape (total number of rows in the dataset and add one column) and type, filled with ones.
arr = np.ones((71, 1)).astype(int)

# Now append the Intercept column to X.
# 'axis=1' means we are adding a colomn. 'axis=0' means we are adding a row.
X = np.append(arr, values = X, axis = 1)

# %%
X
# Out:
# array([[1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00, 1.6534920e+05, 2.3689780e+05, 4.7278420e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00, 2.6259770e+05, 1.8237759e+05, 4.4389853e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00, 1.5344252e+05, 1.7224555e+05, 4.0793454e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00, 2.4437242e+05, 1.3867285e+05, 3.8329962e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00, 1.3220734e+05, 9.2392770e+04, 3.6626842e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00, 2.3287690e+05, 9.9824720e+04, 3.6286236e+05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#         1.0000000e+00, 2.1462546e+05, 2.4729887e+05, 2.2772682e+05],
# ...

# %%
# Splitting dataset into Training set and Test set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# Fitting the first regression model
X_fitted = X_train[:,:]

# Using the Ordinary Least Square (OLS) from 'statsmodels.formula.api' library
reg_1 = sm.OLS(endog = y_train, exog = X_fitted).fit()
reg_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.367
# Model:                            OLS   Adj. R-squared:                  0.290
# Method:                 Least Squares   F-statistic:                     4.740
# Date:                Tue, 15 Oct 2019   Prob (F-statistic):           0.000703
# Time:                        20:40:50   Log-Likelihood:                -682.87
# No. Observations:                  56   AIC:                             1380.
# Df Residuals:                      49   BIC:                             1394.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.153e+04   1.81e+04      3.406      0.001    2.52e+04    9.78e+04
# ...

# %% [markdown]
# ### Looking at the reg_1 summary, it is found the x2 column has highest 'P-value' (indicating its In-Significant). Hence following  'Backward Elimination' process we remove x2 column and re-run our regression, unti we get columns having 'Significant' 'P-value (which is less than 5% or 0.005)'.

# %%
#Fitting the second regression model
X_fitted = X_train[:, [0,1,3,4,5,6,7]]
reg_2 = sm.OLS(endog = y_train, exog = X_fitted).fit()
reg_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.367
# Model:                            OLS   Adj. R-squared:                  0.290
# Method:                 Least Squares   F-statistic:                     4.740
# Date:                Tue, 15 Oct 2019   Prob (F-statistic):           0.000703
# Time:                        20:40:50   Log-Likelihood:                -682.87
# No. Observations:                  56   AIC:                             1380.
# Df Residuals:                      49   BIC:                             1394.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.104e+04   2.59e+04      2.356      0.023    8975.077    1.13e+05
# ...

# %%
#Fitting the second regression model
X_fitted = X_train[:, [0,3,4,5,6,7]]
reg_3 = sm.OLS(endog = y_train, exog = X_fitted).fit()
reg_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.366
# Model:                            OLS   Adj. R-squared:                  0.303
# Method:                 Least Squares   F-statistic:                     5.782
# Date:                Tue, 15 Oct 2019   Prob (F-statistic):           0.000275
# Time:                        20:40:50   Log-Likelihood:                -682.91
# No. Observations:                  56   AIC:                             1378.
# Df Residuals:                      50   BIC:                             1390.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.354e+04   2.38e+04      2.665      0.010    1.56e+04    1.11e+05
# ...

# %%
#Fitting the second regression model
X_fitted = X_train[:, [0,3,4,5,7]]
reg_4 = sm.OLS(endog = y_train, exog = X_fitted).fit()
reg_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.358
# Model:                            OLS   Adj. R-squared:                  0.307
# Method:                 Least Squares   F-statistic:                     7.105
# Date:                Tue, 15 Oct 2019   Prob (F-statistic):           0.000126
# Time:                        20:40:50   Log-Likelihood:                -683.28
# No. Observations:                  56   AIC:                             1377.
# Df Residuals:                      51   BIC:                             1387.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.286e+04   2.09e+04      3.485      0.001    3.09e+04    1.15e+05
# ...

# %%
#Fitting the second regression model
X_fitted = X_train[:, [0,3,4,5]]
reg_5 = sm.OLS(endog = y_train, exog = X_fitted).fit()
reg_5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.350
# Model:                            OLS   Adj. R-squared:                  0.313
# Method:                 Least Squares   F-statistic:                     9.347
# Date:                Tue, 15 Oct 2019   Prob (F-statistic):           4.82e-05
# Time:                        20:40:51   Log-Likelihood:                -683.61
# No. Observations:                  56   AIC:                             1375.
# Df Residuals:                      52   BIC:                             1383.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.256e+04   1.66e+04      4.960      0.000    4.92e+04    1.16e+05
# ...

# %%
#Fitting the second regression model
X_fitted = X_train[:, [0,3,5]]
reg_6 = sm.OLS(endog = y_train, exog = X_fitted).fit()
reg_6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.296
# Method:                 Least Squares   F-statistic:                     12.57
# Date:                Tue, 15 Oct 2019   Prob (F-statistic):           3.41e-05
# Time:                        20:40:51   Log-Likelihood:                -684.81
# No. Observations:                  56   AIC:                             1376.
# Df Residuals:                      53   BIC:                             1382.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       9.645e+04   1.41e+04      6.865      0.000    6.83e+04    1.25e+05
# ...

# %%
#Fitting the second regression model
X_fitted = X_train[:, [0,5]]
reg_7 = sm.OLS(endog = y_train, exog = X_fitted).fit()
reg_7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.305
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     23.71
# Date:                Tue, 15 Oct 2019   Prob (F-statistic):           1.01e-05
# Time:                        20:40:51   Log-Likelihood:                -685.49
# No. Observations:                  56   AIC:                             1375.
# Df Residuals:                      54   BIC:                             1379.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.009e+05   1.35e+04      7.457      0.000    7.38e+04    1.28e+05
# ...

# %% [markdown]
# ### Looking at the above summary, its found that 'x1' which corresponds to IT column in our main dataset. So 'IT' has the high power to predict the profits. In other words, the 'IT' expenses can reflect on the profit. So higher expense on 'IT', higher the profit the company can get.

# %% [markdown]
# ### Additionally, 'R-squared' and 'Adj. R-squared' is about 30%, which means this model is not really powerful. It shows only 30% of the change in the dependent variable.

# %% [markdown]
# ### Finally, lets try to test this model.

# %%
X_for_test = X_test[:, [0,5]]

y_prdicted = reg_7.predict(X_for_test)

# %%
y_prdicted
# Out:
# array([139973.64959926, 136643.40683724, 183925.74133611, 137444.17507912,
#        134578.66151893, 172258.0804173 , 220098.96863325, 150677.78723073,
#        125806.86740006, 135892.52395553, 156045.97680901, 136401.53317771,
#        135213.03881924, 114705.32416075, 126024.39895163])

# %%
y_test
# Out:
# array([205008.32, 203282.38, 191050.39, 208733.99,  97483.56, 156991.12,
#        255752.6 , 134307.35,  96479.52, 107404.34, 156121.95, 202004.64,
#         97427.84,  69758.98,  96722.8 ])

# %% [markdown]
# ### Conclusion - As you can see, 'y_prdicted' values are way away from 'y_test' values, since our prediction is only close to 30%.
