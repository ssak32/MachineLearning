# %%
import pandas as pd

# %%
# Read an .csv file from the location 'http://bit.ly/uforeports' and seperate it with comma.
ufo = pd.read_table('http://bit.ly/uforeports', sep=',')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# Displaying a column under the object 'ufo'
ufo['State']
# Out:
# 0        NY
# 1        NJ
# 2        CO
# 3        KS
# 4        NY
#          ..
# 18236    IL
# 18237    IA
# 18238    WI
# 18239    WI
# 18240    FL
# Name: State, Length: 18241, dtype: object

# %%
# Add new column 'Location' concatenating 'City' & 'State'
ufo['Location'] = ufo.City + ', ' + ufo.State

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
# 'shape' is a tuple which displays number of rows and columns
ufo.shape
# Out:
# (18241, 6)

# %%
# Getting columns datatype
ufo.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# Location           object
# dtype: object

# %%
# Getting column names
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
# Dropping a column
ufo.drop('Colors Reported', axis=1, inplace=True)
ufo.head()
# Out:
#                    City Shape Reported State             Time  \
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
# Dropping more than one column
ufo.drop(['State', 'Time'], axis=1, inplace=True)
ufo.head()
# Out:
#                    City Shape Reported                  Location
# 0                Ithaca       TRIANGLE                Ithaca, NY
# 1           Willingboro          OTHER           Willingboro, NJ
# 2               Holyoke           OVAL               Holyoke, CO
# 3               Abilene           DISK               Abilene, KS
# 4  New York Worlds Fair          LIGHT  New York Worlds Fair, NY

# %%
# Read an .csv file from the location 'http://bit.ly/uforeports' and seperate it with comma.
ufo = pd.read_table('http://bit.ly/uforeports', sep=',')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# Soring a column in 'descending' order.
ufo.State.sort_values(ascending=False).head(25)
# Out:
# 12079    WY
# 11490    WY
# 11333    WY
# 4866     WY
# 3326     WY
# 3328     WY
# 16594    WY
# 1177     WY
# 378      WY
# 5065     WY
# 7684     WY
# 6116     WY
# 10729    WY
# 12072    WY
# 16637    WY
# 14618    WY
# 7491     WY
# 12063    WY
# 14240    WY
# 14586    WY
# 15667    WY
# 7485     WY
# 14747    WY
# 1461     WY
# 1442     WY
# Name: State, dtype: object

# %%
# Alternate way of sorting
ufo.sort_values('City').head()
# Out:
#             City Colors Reported Shape Reported State              Time
# 1761   Abbeville             NaN           DISK    SC   12/10/1968 0:30
# 4553    Aberdeen             NaN       CYLINDER    WA   6/15/1981 22:00
# 16167   Aberdeen             NaN        VARIOUS    OH    3/29/2000 3:00
# 14703   Aberdeen             NaN       TRIANGLE    WA   9/30/1999 21:00
# 389     Aberdeen          ORANGE         CIRCLE    SD  11/15/1956 18:30

# %%
# Sorting by multiple values.
ufo.sort_values(['City', 'State']).head(25)
# Out:
#                       City Colors Reported Shape Reported State  \
# 1761             Abbeville             NaN           DISK    SC
# 2297              Aberdeen             NaN       TRIANGLE    MD
# 9404              Aberdeen             NaN           DISK    MD
# 16167             Aberdeen             NaN        VARIOUS    OH
# 389               Aberdeen          ORANGE         CIRCLE    SD
# 4553              Aberdeen             NaN       CYLINDER    WA
# 12294             Aberdeen             NaN       FIREBALL    WA
# 14703             Aberdeen             NaN       TRIANGLE    WA
# 17809             Aberdeen           GREEN       FIREBALL    WA
# 3                  Abilene             NaN           DISK    KS
# 8783               Abilene             NaN            NaN    KS
# 6654               Abilene             NaN       TRIANGLE    TX
# 8357               Abilene             NaN         SPHERE    TX
# 10883              Abilene             NaN            NaN    TX
# ...
